# %%
import pandas as pd
df=pd.read_csv("file1.csv")

# %%
display(df)
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#Select first 5 rows

df.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
#Selecting last 5 columns

df.tail()
# Out:
#      Customer   ST GENDER Education Customer Lifetime Value  Income  \
# 4003      NaN  NaN    NaN       NaN                     NaN     NaN
# 4004      NaN  NaN    NaN       NaN                     NaN     NaN
# 4005      NaN  NaN    NaN       NaN                     NaN     NaN
# 4006      NaN  NaN    NaN       NaN                     NaN     NaN
# 4007      NaN  NaN    NaN       NaN                     NaN     NaN
#
#       Monthly Premium Auto Number of Open Complaints Policy Type  \
# 4003                   NaN                       NaN         NaN
# 4004                   NaN                       NaN         NaN
# 4005                   NaN                       NaN         NaN
# 4006                   NaN                       NaN         NaN
# 4007                   NaN                       NaN         NaN
#
#      Vehicle Class  Total Claim Amount
# 4003           NaN                 NaN
# 4004           NaN                 NaN
# 4005           NaN                 NaN
# ...

# %%
#Select a single column using single brackets and the name of the column as shown below

df['GENDER']
# Out:
# 0       NaN
# 1         F
# 2         F
# 3         M
# 4         M
#        ...
# 4003    NaN
# 4004    NaN
# 4005    NaN
# 4006    NaN
# 4007    NaN
# Name: GENDER, Length: 4008, dtype: object

# %%
#Select multiple columns

df[['Customer','ST']]
# Out:
#      Customer          ST
# 0     RB50392  Washington
# 1     QZ44356     Arizona
# 2     AI49188      Nevada
# 3     WW63253  California
# 4     GA49547  Washington
# ...       ...         ...
# 4003      NaN         NaN
# 4004      NaN         NaN
# 4005      NaN         NaN
# 4006      NaN         NaN
# 4007      NaN         NaN
#
# [4008 rows x 2 columns]

# %%
df.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
df['Customer'].tail(30)
# Out:
# 3978    NaN
# 3979    NaN
# 3980    NaN
# 3981    NaN
# 3982    NaN
# 3983    NaN
# 3984    NaN
# 3985    NaN
# 3986    NaN
# 3987    NaN
# 3988    NaN
# 3989    NaN
# 3990    NaN
# 3991    NaN
# 3992    NaN
# 3993    NaN
# 3994    NaN
# 3995    NaN
# 3996    NaN
# 3997    NaN
# 3998    NaN
# 3999    NaN
# 4000    NaN
# 4001    NaN
# 4002    NaN
# 4003    NaN
# 4004    NaN
# 4005    NaN
# 4006    NaN
# 4007    NaN
# Name: Customer, dtype: object

# %%
# Strip leading and trailing spaces from a string series


df['Education'].str.strip()

df['Education'].head(10)
# Out:
# 0                  Master
# 1                Bachelor
# 2                Bachelor
# 3                Bachelor
# 4    High School or Below
# 5                Bachelor
# 6                 College
# 7                  Master
# 8                Bachelor
# 9                 College
# Name: Education, dtype: object

# %%
# lowercase all strings in a series


df['ST'].str.lower()
df['ST_lower'].head()
# Out:
# 0    washington
# 1       arizona
# 2        nevada
# 3    california
# 4    washington
# Name: ST_lower, dtype: object

# %%
# calculate using two columns

df['min_revenue'] = df['Monthly Premium Auto'] * df['Income']
df[['Monthly Premium Auto', 'Income', 'min_revenue']].head()
# Out:
#    Monthly Premium Auto   Income  min_revenue
# 0                1000.0      0.0          0.0
# 1                  94.0      0.0          0.0
# 2                 108.0  48767.0    5266836.0
# 3                 106.0      0.0          0.0
# 4                  68.0  36357.0    2472276.0

# %%
 #Get the median grouped by type of room and year
    
    
df[['ST', 'Income', 'Customer']].groupby(['Customer','ST' ], as_index=True).mean()
# Out:
#                       Income
# Customer ST
# AA71604  Arizona     87560.0
# AB13432  California      0.0
# AB60627  Cali        77517.0
# AB72731  California  28358.0
# AB96670  California      0.0
# ...                      ...
# ZX23819  Oregon          0.0
# ZX64745  California      0.0
# ZX86243  Arizona     70247.0
# ZZ91716  California      0.0
# ZZ97035  California      0.0
#
# [1071 rows x 1 columns]

# %%
# get all rows with price < 1000

df_under_50000 = df[df['Income'] >150000]

df.head(30)
# Out:
#    Customer          ST GENDER             Education Customer Lifetime Value  \
# 0   RB50392  Washington    NaN                Master                     NaN
# 1   QZ44356     Arizona      F              Bachelor              697953.59%
# 2   AI49188      Nevada      F              Bachelor             1288743.17%
# 3   WW63253  California      M              Bachelor              764586.18%
# 4   GA49547  Washington      M  High School or Below              536307.65%
# 5   OC83172      Oregon      F              Bachelor              825629.78%
# 6   XZ87318      Oregon      F               College              538089.86%
# 7   CF85061     Arizona      M                Master              721610.03%
# 8   DY87989      Oregon      M              Bachelor             2412750.40%
# 9   BQ94931      Oregon      F               College              738817.81%
# 10  SX51350  California      M               College              473899.20%
# ...

# %%
df.iloc[200]
# Out:
# Customer                           SL22297
# ST                              California
# GENDER                                   F
# Education                           Master
# Customer Lifetime Value        1114030.25%
# Income                             27679.0
# Monthly Premium Auto                 150.0
# Number of Open Complaints           1/0/00
# Policy Type                  Personal Auto
# Vehicle Class                          SUV
# Total Claim Amount              722.486994
# Name: 200, dtype: object

# %%
df.shape
# Out:
# (4008, 11)

# %%
temp_df = df.append(df)  # make a new copy

temp_df.drop_duplicates(inplace=True, keep=False)

temp_df
# Out:
# Empty DataFrame
# Columns: [Customer, ST, GENDER, Education, Customer Lifetime Value, Income, Monthly Premium Auto, Number of Open Complaints, Policy Type, Vehicle Class, Total Claim Amount]
# Index: []

# %%
df.shape
# Out:
# (1072, 11)

# %%
df['Customer'].duplicated().sum()
# Out:
# 2936

# %%
df.set_index('Total Claim Amount', inplace=True)

df
# Out:
#                    Customer          ST GENDER             Education   Income  \
# Total Claim Amount
# 2.704934            RB50392  Washington    NaN                Master      0.0
# 1131.464935         QZ44356     Arizona      F              Bachelor      0.0
# 566.472247          AI49188      Nevada      F              Bachelor  48767.0
# 529.881344          WW63253  California      M              Bachelor      0.0
# 17.269323           GA49547  Washington      M  High School or Below  36357.0
# ...                     ...         ...    ...                   ...      ...
# NaN                     NaN         NaN    NaN                   NaN      NaN
# NaN                     NaN         NaN    NaN                   NaN      NaN
# NaN                     NaN         NaN    NaN                   NaN      NaN
# NaN                     NaN         NaN    NaN                   NaN      NaN
# NaN                     NaN         NaN    NaN                   NaN      NaN
#
# ...

# %%
df
# Out:
#                         Customer          ST GENDER             Education  \
# Customer Lifetime Value
# NaN                      RB50392  Washington    NaN                Master
# 697953.59%               QZ44356     Arizona      F              Bachelor
# 1288743.17%              AI49188      Nevada      F              Bachelor
# 764586.18%               WW63253  California      M              Bachelor
# 536307.65%               GA49547  Washington      M  High School or Below
# ...                          ...         ...    ...                   ...
# NaN                          NaN         NaN    NaN                   NaN
# NaN                          NaN         NaN    NaN                   NaN
# NaN                          NaN         NaN    NaN                   NaN
# NaN                          NaN         NaN    NaN                   NaN
# NaN                          NaN         NaN    NaN                   NaN
#
# ...

# %%
df.drop_duplicates(inplace=False)
# Out:
#                    Customer          ST GENDER             Education   Income  \
# Total Claim Amount
# 2.704934            RB50392  Washington    NaN                Master      0.0
# 1131.464935         QZ44356     Arizona      F              Bachelor      0.0
# 566.472247          AI49188      Nevada      F              Bachelor  48767.0
# 529.881344          WW63253  California      M              Bachelor      0.0
# 17.269323           GA49547  Washington      M  High School or Below  36357.0
# ...                     ...         ...    ...                   ...      ...
# 207.320041          VJ51327        Cali      F  High School or Below  63209.0
# 633.600000          GS98873     Arizona      F              Bachelor  16061.0
# 547.200000          CW49887  California      F                Master  79487.0
# 537.600000          MY31220  California      F               College  54230.0
# NaN                     NaN         NaN    NaN                   NaN      NaN
#
# ...

# %%
df
# Out:
#                    Customer          ST GENDER             Education   Income  \
# Total Claim Amount
# 2.704934            RB50392  Washington    NaN                Master      0.0
# 1131.464935         QZ44356     Arizona      F              Bachelor      0.0
# 566.472247          AI49188      Nevada      F              Bachelor  48767.0
# 529.881344          WW63253  California      M              Bachelor      0.0
# 17.269323           GA49547  Washington      M  High School or Below  36357.0
# ...                     ...         ...    ...                   ...      ...
# 207.320041          VJ51327        Cali      F  High School or Below  63209.0
# 633.600000          GS98873     Arizona      F              Bachelor  16061.0
# 547.200000          CW49887  California      F                Master  79487.0
# 537.600000          MY31220  California      F               College  54230.0
# NaN                     NaN         NaN    NaN                   NaN      NaN
#
# ...

# %%
df.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Income',
#        'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type',
#        'Vehicle Class'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# dtype: object
